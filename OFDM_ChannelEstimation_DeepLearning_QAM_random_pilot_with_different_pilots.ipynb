# %%
from __future__ import division
import numpy as np
import scipy.interpolate 
import tensorflow as tf
import math
import os



#from lpdec.imports import *
K = 64
CP = K//4
P = 8 # number of pilot carriers per OFDM block
#pilotValue = 1+1j
allCarriers = np.arange(K)  # indices of all subcarriers ([0, 1, ... K-1])
pilotCarriers = allCarriers[::K//P] # Pilots is every (K/P)th carrier.
#pilotCarriers = np.hstack([pilotCarriers, np.array([allCarriers[-1]])])
#P = P+1
dataCarriers = np.delete(allCarriers, pilotCarriers)
mu = 2
payloadBits_per_OFDM = len(dataCarriers)*mu  # number of payload bits per OFDM symbol
#payloadBits_per_OFDM = K*mu
SNRdb = 20  # signal to noise-ratio in dB at the receiver 
Clipping_Flag = False

mapping_table = {
    (0,0) : -1-1j,
    (0,1) : -1+1j,
    (1,0) : 1-1j,
    (1,1) : 1+1j,
}

demapping_table = {v : k for k, v in mapping_table.items()}

def Clipping (x, CL):
    sigma = np.sqrt(np.mean(np.square(np.abs(x))))
    CL = CL*sigma
    x_clipped = x  
    clipped_idx = abs(x_clipped) > CL
    x_clipped[clipped_idx] = np.divide((x_clipped[clipped_idx]*CL),abs(x_clipped[clipped_idx]))
    #print (sum(abs(x_clipped_temp-x_clipped)))
    return x_clipped

def PAPR (x):
    Power = np.abs(x)**2
    PeakP = np.max(Power)
    AvgP = np.mean(Power)
    PAPR_dB = 10*np.log10(PeakP/AvgP)
    return PAPR_dB

def Modulation(bits):                                        
    bit_r = bits.reshape((int(len(bits)/mu), mu))                  
    return (2*bit_r[:,0]-1)+1j*(2*bit_r[:,1]-1)  # This is just for QAM modulation

def OFDM_symbol(Data):
    symbol = np.zeros(K, dtype=complex) # the overall K subcarriers
    #symbol = np.zeros(K) 
    symbol[pilotCarriers] = pilotValue  # allocate the pilot subcarriers 
    symbol[dataCarriers] = Data  # allocate the pilot subcarriers
    return symbol

#print("OFDM_data:", OFDM_data)
#print ("Number of OFDM carriers in frequency domain: ", len(OFDM_data))
def IDFT(OFDM_data):
    return np.fft.ifft(OFDM_data)

#print ("Number of OFDM samples in time-domain before CP: ", len(OFDM_time))
def addCP(OFDM_time):
    cp = OFDM_time[-CP:]               # take the last CP samples ...
    return np.hstack([cp, OFDM_time])  # ... and add them to the beginning

#print ("Number of OFDM samples in time domain with CP: ", len(OFDM_withCP))
def channel(signal,channelResponse,SNRdb):
    convolved = np.convolve(signal, channelResponse)
    signal_power = np.mean(abs(convolved**2))
    sigma2 = signal_power * 10**(-SNRdb/10)  # calculate noise power based on signal power and SNR   
    # Generate complex noise with given variance
    noise = np.sqrt(sigma2/2) * (np.random.randn(*convolved.shape)+1j*np.random.randn(*convolved.shape))
    return convolved + noise

def removeCP(signal):
    return signal[CP:(CP+K)]

def DFT(OFDM_RX):
    return np.fft.fft(OFDM_RX)

def equalize(OFDM_demod, Hest):
    return OFDM_demod / Hest

def get_payload(equalized):
    return equalized[dataCarriers]

def PS(bits):
    return bits.reshape((-1,))

def ofdm_simulate(codeword, channelResponse,SNRdb):           
    #H_exact = np.fft.fft(channelResponse, K)        
    # --- training inputs ----
    bits = np.random.binomial(n=1, p=0.5, size=(payloadBits_per_OFDM, ))    
    QAM = Modulation(bits)
    #QAM = 2*bits - 1 + (2*np.random.binomial(n=1, p=0.5, size=(payloadBits_per_OFDM, ))-1)*1j
    #OFDM_data = OFDM_symbol(QAM)
    OFDM_data = np.zeros(K, dtype=complex)
    OFDM_data[pilotCarriers] = pilotValue  # allocate the pilot subcarriers 
    OFDM_data[dataCarriers] = QAM
    #print(OFDM_data) 
    OFDM_time = IDFT(OFDM_data)
    OFDM_withCP = addCP(OFDM_time)
    OFDM_TX = OFDM_withCP
    if Clipping_Flag:
        OFDM_TX = Clipping(OFDM_TX,CR)                            # add clipping 
    OFDM_RX = channel(OFDM_TX, channelResponse,SNRdb)
    OFDM_RX_noCP = removeCP(OFDM_RX)
    #OFDM_RX_noCP = DFT(OFDM_RX_noCP)
    #OFDM_demod = DFT(OFDM_RX_noCP)
    #OFDM_demod[dataCarriers] = 0
    #OFDM_RX_noCP = IDFT(OFDM_demod)
    #pilots = DFT(OFDM_RX_noCP)[pilotCarriers])
    # ----- target inputs ---
    symbol = np.zeros(K, dtype=complex)
    codeword_qam = Modulation(codeword)
    #codeword_qam = 2*codeword - 1 +(2*np.random.binomial(n=1, p=0.5, size=(K, ))-1)*1j
    #print ('before assignment', symbol)
    #symbol[np.arange(K)] = codeword_qam
    if len(codeword_qam) != K:
        print ('length of code word is not equal to K, error !!')
    symbol = codeword_qam
    #print ('after assignment', symbol)
    #print ('code word qam', codeword_qam)
    OFDM_data_codeword = symbol
    OFDM_time_codeword = np.fft.ifft(OFDM_data_codeword)
    OFDM_withCP_cordword = addCP(OFDM_time_codeword)
    if Clipping_Flag:
        OFDM_withCP_cordword = Clipping(OFDM_withCP_cordword,CR) # add clipping 
    OFDM_RX_codeword = channel(OFDM_withCP_cordword, channelResponse,SNRdb)
    OFDM_RX_noCP_codeword = removeCP(OFDM_RX_codeword)
    #OFDM_RX_noCP_codeword = DFT(OFDM_RX_noCP_codeword)
    #print(symbol.size,OFDM_time_codeword.size, OFDM_RX_codeword.size, OFDM_RX_noCP.size,OFDM_RX_noCP_codeword.size )
    return np.concatenate((np.concatenate((np.real(OFDM_RX_noCP),np.imag(OFDM_RX_noCP))), np.concatenate((np.real(OFDM_RX_noCP_codeword),np.imag(OFDM_RX_noCP_codeword))))), abs(channelResponse) #sparse_mask

def ofdm_simulate_single_without_CP(codeword, channelResponse):  
    codeword_qam = Modulation(codeword)
    OFDM_data_codeword = OFDM_symbol(codeword_qam)
    OFDM_time_codeword = np.fft.ifft(OFDM_data_codeword)
    # using a new ofdm symbol for the prefix
    bits = np.random.binomial(n=1, p=0.5, size=(payloadBits_per_OFDM, ))
    codeword_noise = Modulation(codeword)
    OFDM_data_nosie = OFDM_symbol(codeword_noise)
    OFDM_time_noise = np.fft.ifft(OFDM_data_nosie)   
    cp = OFDM_time_noise[-CP:]               # take the last CP samples ...
    OFDM_withCP_cordword = np.hstack([cp,OFDM_time_codeword])
    OFDM_RX_codeword = channel(OFDM_withCP_cordword, channelResponse)
    OFDM_RX_noCP_codeword = removeCP(OFDM_RX_codeword)
    #return np.concatenate((np.real(OFDM_RX_noCP_codeword),np.imag(OFDM_RX_noCP_codeword))) , abs(channelResponse) #sparse_mask
    return np.concatenate((np.real(OFDM_RX_noCP_codeword),np.imag(OFDM_RX_noCP_codeword))), abs(channelResponse)

Pilot_file_name = 'Pilot_'+str(P)
if os.path.isfile(Pilot_file_name):
    print ('Load Training Pilots txt')
    # load file
    bits = np.loadtxt(Pilot_file_name, delimiter=',')
else:
    # write file
    bits = np.random.binomial(n=1, p=0.5, size=(P*mu, ))
    np.savetxt(Pilot_file_name, bits, delimiter=',')
pilotValue = Modulation(bits)
CR = 1
# Out:
# Load Training Pilots txt

# %%
def training():        
        # Training parameters
        #learning_rate = 0.01
        training_epochs = 100
        batch_size = 256
        display_step = 5
        test_step = 10
        examples_to_show = 20

        # Network Parameters
        n_hidden_1 = 500
        n_hidden_2 = 250 # 1st layer num features
        n_hidden_3 = 120 # 2nd layer num features
        n_input = 256 # MNIST data input (img shape: 28*28)
        n_output = 16 #4
        # tf Graph input (only pictures)
        X = tf.placeholder("float", [None, n_input])
        #Y = tf.placeholder("float", [None, K*mu])
        Y = tf.placeholder("float", [None, n_output])
        def encoder(x):
            weights = {                    
                'encoder_h1': tf.Variable(tf.truncated_normal([n_input, n_hidden_1],stddev=0.1)),
                'encoder_h2': tf.Variable(tf.truncated_normal([n_hidden_1, n_hidden_2],stddev=0.1)),
                'encoder_h3': tf.Variable(tf.truncated_normal([n_hidden_2, n_hidden_3],stddev=0.1)),
                'encoder_h4': tf.Variable(tf.truncated_normal([n_hidden_3, n_output],stddev=0.1)),            
            }
            biases = {            
                'encoder_b1': tf.Variable(tf.truncated_normal([n_hidden_1],stddev=0.1)),
                'encoder_b2': tf.Variable(tf.truncated_normal([n_hidden_2],stddev=0.1)),
                'encoder_b3': tf.Variable(tf.truncated_normal([n_hidden_3],stddev=0.1)),
                'encoder_b4': tf.Variable(tf.truncated_normal([n_output],stddev=0.1)),          
            
            }        
            # Encoder Hidden layer with sigmoid activation #1
            #layer_1 = tf.nn.sigmoid(tf.add(tf.matmul(x, weights['encoder_h1']), biases['encoder_b1']))
            layer_1 = tf.nn.relu(tf.add(tf.matmul(x, weights['encoder_h1']), biases['encoder_b1']))
            layer_2 = tf.nn.relu(tf.add(tf.matmul(layer_1, weights['encoder_h2']), biases['encoder_b2']))
            layer_3 = tf.nn.relu(tf.add(tf.matmul(layer_2, weights['encoder_h3']), biases['encoder_b3']))
            layer_4 = tf.nn.sigmoid(tf.add(tf.matmul(layer_3, weights['encoder_h4']), biases['encoder_b4']))
            return layer_4
        # Building the decoder
 
        y_pred = encoder(X)
        # Targets (Labels) are the input data.
        y_true = Y

        # Define loss and optimizer, minimize the squared error
        cost = tf.reduce_mean(tf.pow(y_true - y_pred, 2))
        learning_rate = tf.placeholder(tf.float32, shape=[])
        optimizer = tf.train.RMSPropOptimizer(learning_rate=learning_rate).minimize(cost)

        # Initializing the variables
        init = tf.global_variables_initializer()

        info_len = 32
        code_len = 64
        #bits = np.random.binomial(n=1, p=0.5, size=(36, ))
        #encoded = code.encode(bits)        

        # Start Training
        config = tf.ConfigProto()
        config.gpu_options.allow_growth = True
        # The H information set
        H_folder = '/home/aabbasloo/Desktop/dnn/OFDM_DNN/H_dataset/H_dataset/'
        train_idx_low = 1
        train_idx_high = 301
        test_idx_low = 301
        test_idx_high = 401
        # Saving Channel conditions to a large matrix
        channel_response_set_train = []
        for train_idx in range(train_idx_low,train_idx_high):
            H_file = H_folder + str(train_idx) + '.txt'
            with open(H_file) as f:
                for line in f:
                    numbers_str = line.split()
                    numbers_float = [float(x) for x in numbers_str]
                    h_response = np.asarray(numbers_float[0:int(len(numbers_float)/2)])+1j*np.asarray(numbers_float[int(len(numbers_float)/2):len(numbers_float)])
                    channel_response_set_train.append(h_response)
        
        channel_response_set_test = []
        for test_idx in range(test_idx_low,test_idx_high):
            H_file = H_folder + str(test_idx) + '.txt'
            with open(H_file) as f:
                for line in f:
                    numbers_str = line.split()
                    numbers_float = [float(x) for x in numbers_str]
                    h_response = np.asarray(numbers_float[0:int(len(numbers_float)/2)])+1j*np.asarray(numbers_float[int(len(numbers_float)/2):len(numbers_float)])
                    channel_response_set_test.append(h_response)

        with tf.Session(config=config) as sess:
            sess.run(init)
            learning_rate_current = 0.001   #0.01 
            for epoch in range(training_epochs):
                print(epoch)
                if epoch > 0 and epoch%20 ==0:
                    learning_rate_current = learning_rate_current/5                    
                avg_cost = 0.
                total_batch = 50        

                for index_m in range(total_batch):
                    input_samples = []
                    input_labels = []
                    for index_k in range(0, 1000):
                        bits = np.random.binomial(n=1, p=0.5, size=(K*mu, ))
                        channel_response = channel_response_set_train[np.random.randint(0,len(channel_response_set_train))]
                        signal_output, para = ofdm_simulate(bits,channel_response,SNRdb)   
                        input_labels.append(bits[16:32])
                        input_samples.append(signal_output)
 
                    batch_x = np.asarray(input_samples)
                    batch_y = np.asarray(input_labels)
                    #print(np.asarray(code_words).shape)
                    _,c = sess.run([optimizer,cost], feed_dict={X:batch_x,
                                                                Y:batch_y,
                                                                learning_rate:learning_rate_current})
                    avg_cost += c / total_batch
                if epoch % display_step == 0:
                    print("Epoch:",'%04d' % (epoch+1), "cost=", \
                       "{:.9f}".format(avg_cost))
                    input_samples_test = []
                    input_labels_test = []
                    test_number = 1000
                    # set test channel response for this epoch                    
                    if epoch % test_step == 0:
                        print ("Big Test Set ")
                        test_number = 10000
                    for i in range(0, test_number):
                        bits = np.random.binomial(n=1, p=0.5, size=(K*mu, )) 
                        channel_response= channel_response_set_test[np.random.randint(0,len(channel_response_set_test))]
                        signal_output, para = ofdm_simulate(bits,channel_response,SNRdb)
                        input_labels_test.append(bits[16:32])
                        #input_samples_test.append(np.concatenate((signal_train,signal_output)))
                        input_samples_test.append(signal_output)
                    batch_x = np.asarray(input_samples_test)
                    batch_y = np.asarray(input_labels_test)
                    encode_decode = sess.run(y_pred, feed_dict = {X:batch_x})
                    mean_error = tf.reduce_mean(abs(y_pred - batch_y))
                    mean_error_rate = 1-tf.reduce_mean(tf.reduce_mean(tf.to_float(tf.equal(tf.sign(y_pred-0.5), tf.cast(tf.sign(batch_y-0.5),tf.float32))),1))
                    print("OFDM Detection QAM output number is 4, SNR = ", SNRdb, "Num Pilot", P,"prediction and the mean error on test set are:", mean_error.eval({X:batch_x}), mean_error_rate.eval({X:batch_x}))
                  
                    batch_x = np.asarray(input_samples)
                    batch_y = np.asarray(input_labels)
                    encode_decode = sess.run(y_pred, feed_dict = {X:batch_x})
                    mean_error = tf.reduce_mean(abs(y_pred - batch_y))                    
                    mean_error_rate = 1-tf.reduce_mean(tf.reduce_mean(tf.to_float(tf.equal(tf.sign(y_pred-0.5), tf.cast(tf.sign(batch_y-0.5),tf.float32))),1))
                    print("prediction and the mean error on train set are:", mean_error.eval({X:batch_x}), mean_error_rate.eval({X:batch_x}))
                    
            print("optimization finished")

# %%
training()
# Out:
# 0
# Epoch: 0001 cost= 0.252852422
# Big Test Set
# OFDM Detection QAM output number is 4, SNR =  20 Num Pilot 8 prediction and the mean error on test set are: 0.49979556 0.49775624
# prediction and the mean error on train set are: 0.49994612 0.50325
# 1
# 2
# 3
# 4
# 5
# Epoch: 0006 cost= 0.242410435
# OFDM Detection QAM output number is 4, SNR =  20 Num Pilot 8 prediction and the mean error on test set are: 0.47318515 0.35325003
# prediction and the mean error on train set are: 0.47210577 0.34375
# 6
# 7
# 8
# 9
# 10
# Epoch: 0011 cost= 0.071950383
# Big Test Set
# OFDM Detection QAM output number is 4, SNR =  20 Num Pilot 8 prediction and the mean error on test set are: 0.18343695 0.07439375
# prediction and the mean error on train set are: 0.18365374 0.076687515
# 11
# 12
# 13
# 14
# 15
# Epoch: 0016 cost= 0.042583944
# OFDM Detection QAM output number is 4, SNR =  20 Num Pilot 8 prediction and the mean error on test set are: 0.11112924 0.059000015
# prediction and the mean error on train set are: 0.10690153 0.053937495
# 16
# 17
# 18
# 19
# 20
# Epoch: 0021 cost= 0.034309142
# Big Test Set
# OFDM Detection QAM output number is 4, SNR =  20 Num Pilot 8 prediction and the mean error on test set are: 0.08310442 0.046168745
# prediction and the mean error on train set are: 0.08346552 0.044624984
# 21
# 22
# 23
# 24
# 25
# Epoch: 0026 cost= 0.032287506
# OFDM Detection QAM output number is 4, SNR =  20 Num Pilot 8 prediction and the mean error on test set are: 0.07534822 0.040875018
# prediction and the mean error on train set are: 0.07470246 0.039125025
# 26
# 27
# 28
# 29
# 30
# Epoch: 0031 cost= 0.030014210
# Big Test Set
# OFDM Detection QAM output number is 4, SNR =  20 Num Pilot 8 prediction and the mean error on test set are: 0.07160197 0.039981246
# prediction and the mean error on train set are: 0.067950666 0.034749985
# 31
# 32
# 33
# 34
# 35
# Epoch: 0036 cost= 0.028200400
# OFDM Detection QAM output number is 4, SNR =  20 Num Pilot 8 prediction and the mean error on test set are: 0.071673326 0.04000002
# prediction and the mean error on train set are: 0.06508965 0.036125004
# 36
# 37
# 38
# 39
# 40
# Epoch: 0041 cost= 0.026198576
# Big Test Set
# OFDM Detection QAM output number is 4, SNR =  20 Num Pilot 8 prediction and the mean error on test set are: 0.067292824 0.038131237
# prediction and the mean error on train set are: 0.065303884 0.035937488
# 41
# 42
# 43
# 44
# 45
# Epoch: 0046 cost= 0.025730863
# OFDM Detection QAM output number is 4, SNR =  20 Num Pilot 8 prediction and the mean error on test set are: 0.06528692 0.03468752
# prediction and the mean error on train set are: 0.064333424 0.033062518
# 46
# 47
# 48
# 49
# 50
# Epoch: 0051 cost= 0.025280729
# Big Test Set
# OFDM Detection QAM output number is 4, SNR =  20 Num Pilot 8 prediction and the mean error on test set are: 0.06442454 0.034362495
# prediction and the mean error on train set are: 0.06400885 0.035812497
# 51
# 52
# 53
# 54
# 55
# Epoch: 0056 cost= 0.024945492
# OFDM Detection QAM output number is 4, SNR =  20 Num Pilot 8 prediction and the mean error on test set are: 0.064285666 0.034437478
# prediction and the mean error on train set are: 0.06560838 0.035749972
# 56
# 57
# 58
# 59
# 60
# Epoch: 0061 cost= 0.024234698
# Big Test Set
# OFDM Detection QAM output number is 4, SNR =  20 Num Pilot 8 prediction and the mean error on test set are: 0.061592285 0.032137513
# prediction and the mean error on train set are: 0.062315956 0.03275001
# 61
# 62
# 63
# 64
# 65
# Epoch: 0066 cost= 0.024382785
# OFDM Detection QAM output number is 4, SNR =  20 Num Pilot 8 prediction and the mean error on test set are: 0.05623527 0.030125022
# prediction and the mean error on train set are: 0.059393365 0.031875014
# 66
# 67
# 68
# 69
# 70
# Epoch: 0071 cost= 0.024355628
# Big Test Set
# OFDM Detection QAM output number is 4, SNR =  20 Num Pilot 8 prediction and the mean error on test set are: 0.06261653 0.033112526
# prediction and the mean error on train set are: 0.06313013 0.034375012
# 71
# 72
# 73
# 74
# 75
# Epoch: 0076 cost= 0.024205871
# OFDM Detection QAM output number is 4, SNR =  20 Num Pilot 8 prediction and the mean error on test set are: 0.06787233 0.035749972
# prediction and the mean error on train set are: 0.062045638 0.03468752
# 76
# 77
# 78
# 79
# 80
# Epoch: 0081 cost= 0.023848949
# Big Test Set
# OFDM Detection QAM output number is 4, SNR =  20 Num Pilot 8 prediction and the mean error on test set are: 0.061522547 0.03254378
# prediction and the mean error on train set are: 0.059884995 0.030375004
# 81
# 82
# 83
# 84
# 85
# Epoch: 0086 cost= 0.023913901
# OFDM Detection QAM output number is 4, SNR =  20 Num Pilot 8 prediction and the mean error on test set are: 0.06575264 0.036812484
# prediction and the mean error on train set are: 0.057558723 0.027125001
# 86
# 87
# 88
# 89
# 90
# Epoch: 0091 cost= 0.024111436
# Big Test Set
# OFDM Detection QAM output number is 4, SNR =  20 Num Pilot 8 prediction and the mean error on test set are: 0.06306651 0.03387499
# prediction and the mean error on train set are: 0.06214873 0.032687485
# 91
# 92
